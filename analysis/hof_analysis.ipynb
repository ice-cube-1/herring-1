# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
data = pd.read_csv("output.csv")
prey_cols = ['alpha','beta','gamma','delta','alive']
predator_cols = ['gamma1','gamma2','k','alive']
prey_data = pd.DataFrame(columns=prey_cols)
predator_data = pd.DataFrame(columns=predator_cols)
for i in range(300):
    prey_data.loc[i] = data.iloc[i*10+5:(i+1)*10][prey_cols].mean()
    predator_data.loc[i] = data.iloc[i*10:i*10+5][predator_cols].mean()

# %%
plt.plot(prey_data["alive"],label='prey')
plt.plot(predator_data["alive"],label='predator')
plt.legend()
plt.show()
plt.plot(prey_data["alpha"])
plt.plot(prey_data["beta"])
plt.show()
plt.plot(prey_data["delta"])
plt.show()
plt.plot(predator_data["gamma1"],label='g1')
plt.plot(predator_data["gamma2"],label='g2')
plt.legend()
plt.show()

# %%
print(predator_data[predator_data.index>150].sort_values("alive",ascending=True).head(10))
print(prey_data[prey_data.index>150].sort_values("alive",ascending=False).head(10))
# Out:
#        gamma1    gamma2         k   alive
# 265  3.567190  1.249500 -0.443831  4553.8
# 219  3.322620  1.283590  0.378771  4586.6
# 258  0.332329  1.283190 -0.339335  4596.0
# 262  1.330500  0.917552  0.101431  4605.0
# 280  3.004250  1.047780 -0.611408  4608.0
# 222  6.000000  0.859689  0.066073  4610.4
# 214  3.441700  0.958532 -0.504288  4611.0
# 285  1.663730  0.961297  0.842018  4625.2
# 191  5.708520  0.695768  0.016797  4632.0
# 253  2.217510  1.626210  0.858443  4632.6
#         alpha     beta     gamma     delta   alive
# 207  0.300651 -6.00000  1.215660  0.000980  4711.6
# 203  0.282701 -6.00000  1.341330  0.001000  4706.2
# 202  0.344370 -6.00000  3.670630  0.000398  4704.8
# 174  0.074931 -4.53825  0.429541  0.001000  4703.8
# 206  0.601231 -4.97677  3.034070  0.000638  4699.2
# 175  0.351307 -3.82199  3.474880  0.000758  4695.4
# 173  0.060225 -6.00000  1.319230  0.001000  4693.2
# 208  0.242736 -4.58434  2.887950  0.000595  4689.8
# 204  0.243211 -4.03687  1.824590  0.000994  4689.8
# 188  0.219295 -6.00000  1.146050  0.000956  4689.2

# %%
plt.plot(prey_data["delta"])
plt.show()
