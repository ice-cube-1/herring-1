# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
data = pd.read_csv("output.csv")
prey_cols = ['alpha','beta','gamma','delta','alive']
predator_cols = ['gamma1','gamma2','k','alive']
prey_data = pd.DataFrame(columns=prey_cols)
predator_data = pd.DataFrame(columns=predator_cols)
for i in range(2000):
    prey_data.loc[i] = data.iloc[i*10+5:(i+1)*10][prey_cols].mean()
    predator_data.loc[i] = data.iloc[i*10:i*10+5][predator_cols].mean()

# %%
plt.plot(prey_data["alive"],label='prey')
plt.plot(predator_data["alive"],label='predator')
plt.legend()
plt.show()
plt.scatter(y=prey_data["alpha"],x=prey_data.index,s=2)
plt.scatter(y=prey_data["beta"],x=prey_data.index,s=2)
plt.show()
plt.scatter(y=prey_data["delta"],x=prey_data.index,s=2)
plt.show()
plt.scatter(y=prey_data["gamma"],x=prey_data.index,s=2)
plt.show()
plt.scatter(y=predator_data["gamma1"],x=predator_data.index,label='g1',s=2)
plt.scatter(y=predator_data["gamma2"],x=predator_data.index,label='g2',s=2)
plt.legend()
plt.show()
plt.scatter(y=predator_data["k"],x=predator_data.index,label='g2',s=2)
plt.show()

# %%
predator_data= predator_data[predator_data.index>200].sort_values("alive",ascending=True)
prey_data = prey_data[prey_data.index>200].sort_values("alive",ascending=False)
print(predator_data.head(10))
print(prey_data.head(10))
# Out:
#        gamma1    gamma2         k   alive
# 215  6.000000  1.308990 -0.105417  4284.2
# 206  0.877176  1.047100 -0.010651  4321.0
# 221  3.493210  1.467290  0.024470  4351.8
# 232  0.953167  0.749474 -0.155882  4359.4
# 301  0.884079  1.000960 -0.143364  4360.8
# 259  3.854290  1.510140  0.530564  4428.8
# 255  5.324960  0.454043  0.032569  4444.4
# 247  1.816650  1.795240  1.000000  4503.2
# 266  1.701740  0.512602 -0.620563  4509.6
# 235  2.632150  2.259880 -0.047578  4523.8
# 283  6.000000  1.651220 -0.714304  4524.6
# 294  2.080860  0.302500 -0.348711  4537.8
# 249  4.787990  0.307737 -0.503763  4540.8
# 234  5.153970  2.522060 -0.500565  4542.2
# 299  4.787990  2.285560 -0.578649  4547.2
#         alpha     beta    gamma         delta   alive
# 293  0.355463 -2.62713  2.36658  1.426130e-04  4422.2
# 283  0.506029 -2.85399  2.50113  1.000000e-08  4420.4
# 205  0.384528 -2.09456  2.68568  4.336390e-04  4419.6
# 206  0.568447 -2.76025  2.55777  8.731790e-05  4411.6
# 287  0.347707 -2.18143  2.95134  1.000000e-08  4411.0
# 252  0.458035 -2.59151  2.52732  1.000000e-08  4409.0
# 282  0.413081 -2.45434  2.51791  1.000000e-08  4408.6
# 274  0.402051 -2.98700  2.93801  1.426130e-04  4407.2
# 280  0.517850 -2.98599  2.31469  1.000000e-08  4407.2
# 298  0.395608 -2.79559  2.52241  2.910360e-04  4405.4
# 214  0.523188 -2.79314  2.49648  1.000000e-08  4400.8
# 284  0.564438 -2.90524  2.23415  1.000000e-08  4399.8
# 254  0.300664 -1.86795  2.54966  2.620240e-05  4398.0
# 288  0.395608 -3.00000  2.41759  1.853940e-04  4398.0
# 217  0.402051 -3.00000  2.93801  1.426130e-04  4397.6

# %%
plt.scatter(prey_data["alpha"],prey_data['alive'],s=2,label='alpha')
plt.scatter(prey_data["beta"],prey_data['alive'],s=2,label='beta')
plt.legend()
plt.show()
plt.scatter(prey_data["alpha"],prey_data['beta'],s=(prey_data['alive']-4400)/4)
plt.show()
plt.scatter(prey_data["delta"],prey_data['alive'],s=2)
plt.show()
plt.scatter(prey_data["gamma"],prey_data['alive'],s=2)
plt.show()
plt.scatter(predator_data["gamma1"],predator_data['gamma2'],c=predator_data['alive'],cmap='coolwarm_r')
plt.show()
plt.scatter(predator_data["gamma1"],predator_data['alive'],label='gamma1',s=2)
plt.scatter(predator_data["gamma2"],predator_data['alive'],label='gamma2',s=2)
plt.legend()
plt.show()
plt.scatter(predator_data["k"],predator_data['alive'],label='g2',s=2)
plt.show()
