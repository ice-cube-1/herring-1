# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
data = pd.read_csv("output.csv")
prey_cols = ['alpha','beta','gamma','delta','alive']
predator_cols = ['gamma1','gamma2','k','alive']
prey_data = pd.DataFrame(columns=prey_cols)
predator_data = pd.DataFrame(columns=predator_cols)
for i in range(225):
    prey_data.loc[i] = data.iloc[i*10+5:(i+1)*10][prey_cols].mean()
    predator_data.loc[i] = data.iloc[i*10:i*10+5][predator_cols].mean()

# %%
plt.plot(prey_data["alive"],label='prey')
plt.plot(predator_data["alive"],label='predator')
plt.legend()
plt.show()
plt.plot(prey_data["alpha"])
plt.plot(prey_data["beta"])
plt.show()
plt.plot(prey_data["delta"])
plt.show()
plt.plot(predator_data["gamma1"],label='g1')
plt.plot(predator_data["gamma2"],label='g2')
plt.legend()
plt.show()

# %%
print(predator_data.sort_values("alive",ascending=True).head(10))
print(prey_data.sort_values("alive",ascending=False).head(10))
# Out:
#       gamma1    gamma2         k   alive
# 182  5.34172  1.180830 -0.510147  4574.6
# 195  3.12298  0.871170 -0.062905  4610.4
# 210  5.36724  0.950768 -0.637928  4617.4
# 218  2.92921  0.703550  0.068789  4630.6
# 200  3.92140  1.534470 -0.610096  4631.0
# 221  1.40281  0.869357  1.000000  4632.4
# 198  5.30848  1.684460 -0.233357  4633.0
# 224  6.00000  0.668173 -0.350780  4643.0
# 202  4.54980  1.910430  0.623682  4665.0
# 190  1.89976  2.425750  0.489621  4702.0
#         alpha     beta    gamma     delta   alive
# 185  0.251527 -4.00000  0.00000  0.000215  4662.8
# 224  0.067280 -3.92702  0.00000  0.000040  4661.0
# 193  0.260089 -4.00000  0.00000  0.000215  4656.4
# 189  0.589293 -3.85417  1.57039  0.000001  4654.2
# 175  0.085277 -3.87745  0.00000  0.000057  4652.8
# 190  0.415986 -3.74991  0.00000  0.000207  4652.6
# 206  0.315013 -3.26679  0.00000  0.000001  4651.2
# 199  0.196624 -4.00000  0.00000  0.000043  4650.6
# 186  0.034380 -3.82844  0.00000  0.000001  4649.6
# 182  0.312640 -3.91422  0.00000  0.000069  4648.8

# %%
plt.plot(prey_data["delta"])
plt.show()
